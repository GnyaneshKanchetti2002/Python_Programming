# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.simplefilter("ignore", UserWarning)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Reading & Data Types

# %%
#Read the data in pandas
inp0= pd.read_csv(r"D:\Phython (Jupitor notebook)\Attribute+DataSet.csv")
inp1= pd.read_csv(r"D:\Phython (Jupitor notebook)\Dress+Sales.csv")

# %% [markdown]
# You have “Attribute DataSet” which contains a column named “Price”. Choose the correct statement from the following about its data type and variable type.
# - Integer type and numerical variable
# - Object type and categorical ordinal variable
# - Object type and categorical nominal variable
# - Float type and categorical variable.

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          477 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB

# %% [markdown]
# There is another column in “Attribute DataSet” named as “Recommendation”, choose the correct statement about its data type and variable type.
# - Integer type and categorical
# - Object type and categorical
# - Integer type and continuous numerical
# - Object type only.

# %%
inp0
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 474   990559192    Brief  Average     4.7     M  winter     o-neck
# 475   713391965   Casual      Low     4.7     M  Spring     o-neck
# 476   532874347   Casual  Average     4.7     M  Summer     v-neck
# 477   655464934   Casual  Average     4.6     L  winter  boat-neck
# 478   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0      sleevless            NaN     chiffon     ruffles       animal
# ...

# %% [markdown]
# Which of the following column do you think are of no use in “Attribute DataSet”.
# - Dress_ID
# - Price
# - Size and material
# - NeckLine
# - None of the above

# %%
# Print the information about the attributes of inp0 and inp1.

# %% [markdown]
# ### Fixing the Rows and Columns

# %% [markdown]
# As you can see, there is a column in “Attribute Dataset” named as ‘Size’. This column contains the values in abbreviation format. Write a code in Python to convert the followings:
#
# - M into  “Medium”
# - L into  “Large”
# - XL into “Extra large”
# - free into “Free”
# - S, s & small into “Small”.
#
# Now once you are done with changes in the dataset, what is the value of the lowest percentage, the highest percentage and the percentage of Small size categories in the column named “Size”?

# %%
def size(x):
    if x == 'M':
        return 'Medium'
    elif x == 'L':
        return 'Large'
    elif x == 'XL':
        return 'Extra large'
    elif x == 'free':
        return 'Free'
    else:
        return 'Small'
sizes = inp0.Size.apply(size)
sizes.value_counts(normalize = True)
# Out:
# Medium         0.356994
# Free           0.344468
# Large          0.194154
# Small          0.075157
# Extra large    0.029228
# Name: Size, dtype: float64

# %%
inp0
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 474   990559192    Brief  Average     4.7     M  winter     o-neck
# 475   713391965   Casual      Low     4.7     M  Spring     o-neck
# 476   532874347   Casual  Average     4.7     M  Summer     v-neck
# 477   655464934   Casual  Average     4.6     L  winter  boat-neck
# 478   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0      sleevless            NaN     chiffon     ruffles       animal
# ...

# %%
# Column fixing, correcting size abbreviation. count the percentage of each size category in "Size" column.
inp0['Size'].value_counts(normalize = True)
# Out:
# M        0.356994
# free     0.344468
# L        0.194154
# S        0.070981
# XL       0.029228
# small    0.002088
# s        0.002088
# Name: Size, dtype: float64

# %%
# Print the value counts of each category in "Size" column.
help(pd.DataFrame.value_counts)
# Out:
# Help on function value_counts in module pandas.core.frame:
#
# value_counts(self, subset: 'Sequence[Hashable] | None' = None, normalize: 'bool' = False, sort: 'bool' = True, ascending: 'bool' = False, dropna: 'bool' = True)
#     Return a Series containing counts of unique rows in the DataFrame.
#
#     .. versionadded:: 1.1.0
#
#     Parameters
#     ----------
#     subset : list-like, optional
#         Columns to use when counting unique combinations.
#     normalize : bool, default False
#         Return proportions rather than frequencies.
#     sort : bool, default True
#         Sort by frequencies.
#     ascending : bool, default False
#         Sort in ascending order.
#     dropna : bool, default True
#         Don’t include counts of rows that contain NA values.
#
#         .. versionadded:: 1.3.0
#
#     Returns
#     -------
#     Series
#
#     See Also
#     --------
#     Series.value_counts: Equivalent method on Series.
#
#     Notes
#     -----
# ...

# %% [markdown]
# ### Impute/Remove Missing values

# %%
inp1
# Out:
#          Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0    1.006033e+09        2114        2274        2491        2660        2727
# 1    1.212192e+09         151         275         570         750         813
# 2    1.190381e+09           6           7           7           7           8
# 3    9.660060e+08        1005        1128        1326        1455        1507
# 4    8.763395e+08         996        1175        1304        1396        1432
# ..            ...         ...         ...         ...         ...         ...
# 474  9.905592e+08           0           0           0          60          62
# 475  7.133920e+08           0           0           0         560         554
# 476  5.328743e+08           0           0           0         734         728
# 477  6.554649e+08           0           0           0         254         259
# 478  9.199310e+08           0           0           0         538         545
#
# ...

# %%
# Print the null count of each variables of inp0 and inp1.
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  479 non-null    object
#  9   14-09-2013  479 non-null    object
#  10  16-09-2013  479 non-null    object
#  11  18-09-2013  479 non-null    object
#  12  20-09-2013  479 non-null    object
#  13  22-09-2013  479 non-null    object
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
# ...

# %% [markdown]
# You are given another dataset named “Dress Sales”. Now if you observe the datatypes of the columns using ‘inp1.info()’ command, you can identify that there are certain columns defined as object data type though they primarily consist of numeric data.
#
# Now if you try and convert these object data type columns into numeric data type(float), you will come across an error message. Try to correct this error.

# %%
#inp1['09-12-2013'] = inp1['09-12-2013'].astype(float)
inp1[inp1['09-12-2013'] == 'Removed']
# Out:
#          Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 263  1.090993e+09           0           0           0          62          64
#
#      09-08-2013  09-10-2013 09-12-2013 14-09-2013  ... 24-09-2013 26-09-2013  \
# 263          77          81    Removed    removed  ...        703        NaN
#
#     28-09-2013 30-09-2013  10-02-2013  10-04-2013  10-06-2013  10-08-2013  \
# 263        753        NaN         NaN         NaN         956         NaN
#
#      10-10-2013  10-12-2013
# 263         NaN        1043
#
# [1 rows x 24 columns]

# %%
# Print the data types information of inp1 i.e. "Dress Sales" data.
inp1.loc[inp1['09-12-2013']== 'Removed',"09-12-2013"] = np.NaN

inp1.loc[inp1['14-09-2013']== 'removed',"14-09-2013"] = np.NaN

inp1.loc[inp1['16-09-2013']== 'removed',"16-09-2013"] = np.NaN

inp1.loc[inp1['18-09-2013']== 'removed',"18-09-2013"] = np.NaN

inp1.loc[inp1['20-09-2013']== 'removed',"20-09-2013"] = np.NaN

inp1.loc[inp1['22-09-2013']== 'Orders',"22-09-2013"] = np.NaN

# %%
# Try to convert the object type into float type of data. YOU GET ERROR MESSAGE.

# %%
# Do the required changes in the "Dress Sales" data set to get null values on string values.

# %%
# Convert the object type columns in "Dress Sales" into float type of data type.
inp1['09-12-2013'] = inp1['09-12-2013'].astype(float)

# %% [markdown]
# When you see the null counts in “Dress Sales” dataset after performing all the operations that have been mentioned in jupyter notebook, you will find that there are some columns in “Dress Sales” data where there are more than 40% of missing values. Based on your understanding of dealing with missing values do the following steps.

# %%
# Print the null percetange of each column of inp1.
inp1.isnull().sum()
# Out:
# Dress_ID        0
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      1
# 14-09-2013      1
# 16-09-2013      1
# 18-09-2013      1
# 20-09-2013      1
# 22-09-2013      1
# 24-09-2013      0
# 26-09-2013    222
# 28-09-2013      0
# 30-09-2013    257
# 10-02-2013    259
# 10-04-2013    258
# 10-06-2013      0
# 10-08-2013    255
# 10-10-2013    255
# 10-12-2013      0
# dtype: int64

# %%
# Drop the columns in "Dress Sales" which have more than 40% of missing values.
inp1.shape
# Out:
# (479, 24)

# %%
12/479
# Out:
# 0.025052192066805846

# %%
inp1= inp1.drop(["26-09-2013"] , axis= 1)

inp1= inp1.drop(["30-09-2013"] , axis= 1)

inp1= inp1.drop(["10-02-2013"] , axis= 1)

inp1= inp1.drop(["10-04-2013"] , axis= 1)

inp1= inp1.drop(["10-08-2013"] , axis= 1)

inp1= inp1.drop(["10-10-2013"] , axis= 1)

# %%
inp1.sum()
# Out:
# C:\Users\GNYANESH\AppData\Local\Temp\ipykernel_24412\1646747750.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inp1.sum()
# Dress_ID      4.321739e+11
# 29-08-2013    9.488300e+04
# 31-08-2013    1.004830e+05
# 09-02-2013    1.070810e+05
# 09-04-2013    1.436000e+05
# 09-06-2013    1.459730e+05
# 09-08-2013    1.516200e+05
# 09-10-2013    1.533280e+05
# 09-12-2013    1.596930e+05
# 24-09-2013    1.786380e+05
# 28-09-2013    1.866140e+05
# 10-06-2013    1.989480e+05
# 10-12-2013    2.079090e+05
# dtype: float64

# %% [markdown]
# You should categorise the dates into seasons in “Dress Sales” data to simplify the analysis according to the following criteria:
# - June, July and August: Summer.
# - September, October and November: Autumn.
# - December, January and February: WInter.
# - March, April and May: Spring.

# %%
# Create the four seasons columns in inp1, according to the above criteria.
Dress = inp1.sum()[1:]
D = pd.DataFrame(Dress, columns = ['Sum'])
D.reset_index(inplace = True)
D.rename(columns = {'index' : 'dates'}, inplace = True)
# Out:
# C:\Users\GNYANESH\AppData\Local\Temp\ipykernel_24412\1792893227.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Dress = inp1.sum()[1:]

# %%
# calculate the sum of sales in each seasons in inp1 i.e. "Dress Sales".
D['Month'] = D.dates.apply(lambda x: float(x.split('-')[1]))
D.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   dates   12 non-null     object
#  1   Sum     12 non-null     float64
#  2   Month   12 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 416.0+ bytes

# %%
def season(x):
    if x in [1,2,12]:
        return 'Winter'
    elif x in [3,4,5]:
        return 'Spring'
    elif x in [6,7,8]:
        return 'Summer'
    else:
        return 'Autumn'
    
D['Season'] = D.Month.apply(season)

# %%
D[D.Season == 'Autumn'].Sum.sum()
# Out:
# 518580.0

# %% [markdown]
# Now let's merge inp1 with inp0 with left join manner, so that the information of inp0 should remain intact.

# %%
# Merge inp0 with inp1 into inp0. this is also called left merge.
inp0 = pd.merge(left=inp0,right=inp1, how='left', left_on='Dress_ID', right_on='Dress_ID')
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#         Material FabricType  ... 09-12-2013 14-09-2013  16-09-2013  \
# 0            NaN    chiffon  ...     3119.0       3204        3277
# 1     microfiber        NaN  ...     1558.0       1756        1878
# 2       polyster        NaN  ...       10.0         10          10
# 3           silk    chiffon  ...     1723.0       1746        1783
# 4  chiffonfabric    chiffon  ...     1638.0       1655        1681
#
#    18-09-2013  20-09-2013  22-09-2013  24-09-2013  28-09-2013  10-06-2013  \
# ...

# %%
# Now Drop the Date columns from inp0 as it is already combined into four seasons.
inp0.drop(inp0.loc[:,'29-08-2013':'10-12-2013'].columns, axis= 1, inplace= True)
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# dtype: int64

# %% [markdown]
# Print the null count of inp0 to get the idea about the missing values in data set.

# %%
# Print the null count of each columns in inp0 dataframe i.e. combined data frame of inp0 and inp1 without date columns.
inp0.isnull().sum()
# Out:
# Dress_ID          0
# Style             0
# Price             0
# Rating            0
# Size              0
# Season            0
# NeckLine          0
# SleeveLength      0
# Material          0
# FabricType        0
# Decoration        0
# Pattern Type      0
# Recommendation    0
# dtype: int64

# %% [markdown]
# You can see that there are two types of variables one with a large number of missing values and another is very less number of missing values. These two columns can be categorized as:
#
# Type-1: Missing values are very less (around 2 or 3 missing values): Price, Season, NeckLine, SleeveLength, Winter and Autumn.
#
# Type-2: Missing values are large in numbers (more than 15%): Material, FabricType, Decoration and Pattern Type.

# %%
# Deal with the missing values of Type-1 columns: Price, Season, NeckLine, SleeveLength, Winter and Autumn.
inp0 = inp0[~inp0.Price.isnull()]

inp0 = inp0[~inp0.Season.isnull()]

inp0 = inp0[~inp0.NeckLine.isnull()]

inp0 = inp0[~inp0.SleeveLength.isnull()]

#inp0 = inp0[~inp0.Winter.isnull()]

#inp0 = inp0[~inp0.Autumn.isnull()]

# %%
inp0
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Autumn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 474   990559192    Brief  Average     4.7     M  Winter     o-neck
# 475   713391965   Casual      Low     4.7     M  Spring     o-neck
# 476   532874347   Casual  Average     4.7     M  Summer     v-neck
# 477   655464934   Casual  Average     4.6     L  Winter  boat-neck
# 478   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#      SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0     sleeve less        Missing     chiffon     ruffles       animal
# ...

# %%
# Deal with the missing values for Type-2 columns: Material, FabricType, Decoration and Pattern Type.
inp0.Material= inp0.Material.replace(np.nan, "Missing")

inp0.FabricType= inp0.FabricType.replace(np.nan, "Missing")

inp0.Decoration= inp0.Decoration.replace(np.nan, "Missing")

inp0['Pattern Type']= inp0['Pattern Type'].replace(np.nan, "Missing")

# %% [markdown]
# ### Standardise value

# %% [markdown]
# In the given dataset, there are certain discrepancies with the categorical names such as irregular spellings. Choose the correct option of columns with irregular categories and update them.
#
# - Season, NeckLine
# - Price, Material
# - fabricType, Decoration
# - Season, SleeveLength

# %%
#correcting the spellings.
inp0.Price.value_counts()
# Out:
# Average      238
# Low          162
# Medium        30
# High          21
# very-high     21
# Name: Price, dtype: int64

# %%
#correcting the Spellings.
inp0.Season= inp0.Season.replace('Automn', "Autumn")

inp0.Season= inp0.Season.replace('spring', "Spring")

inp0.Season= inp0.Season.replace('winter', "Winter")



inp0.SleeveLength= inp0.SleeveLength.replace(['cap-sleeves', 'capsleeves'], "cap sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace('full', "full sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace(['half','halfsleeve'], "half sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace(['sleevless', 'sleeevless', 'sleeveless', 'sleveless'], "sleeve less")

inp0.SleeveLength= inp0.SleeveLength.replace(['threequarter','threequater', 'thressqatar'], "three quater")

inp0.SleeveLength= inp0.SleeveLength.replace(['turndowncollor','urndowncollor'], "turn down collar")

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Unordered Univariate Analysis

# %% [markdown]
# There is a column named ‘Style’ in ‘Attribute Dataset’ which consists of the different style categories of the women apparels. Certain categories whose total sale is less than 50000 across all the seasons is considered under one single category as ‘Others’.

# %% [markdown]
# Which of the following categories in ‘Style’ column can be grouped into ‘Others’ category? and perform the grouping operation in the notebook for further analysis.
# - Flare, fashion
# - Novelty, bohemian
# - OL, fashion, work
# - Novelty, fashion, Flare

# %%
# Group "Style" categories into "Others" which have less than 50000 sales across all the seasons.
inp4 = pd.read_csv(r"D:\Phython (Jupitor notebook)\Attribute+DataSet.csv")
inp5 = pd.read_csv(r"D:\Phython (Jupitor notebook)\Dress+Sales.csv")
data = inp5.merge(inp4, on = 'Dress_ID', how = 'left')
data
# Out:
#          Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0    1.006033e+09        2114        2274        2491        2660        2727
# 1    1.212192e+09         151         275         570         750         813
# 2    1.190381e+09           6           7           7           7           8
# 3    9.660060e+08        1005        1128        1326        1455        1507
# 4    8.763395e+08         996        1175        1304        1396        1432
# ..            ...         ...         ...         ...         ...         ...
# 474  9.905592e+08           0           0           0          60          62
# 475  7.133920e+08           0           0           0         560         554
# 476  5.328743e+08           0           0           0         734         728
# 477  6.554649e+08           0           0           0         254         259
# 478  9.199310e+08           0           0           0         538         545
#
# ...

# %%
data1 = data.groupby('Style').sum()
data1.drop(['Dress_ID','Rating','Recommendation'], axis = 1, inplace = True)

# %%
#help(pd.DataFrame.sum)
data1.sum(axis = 1)
# Out:
# Style
# Brief       106269.0
# Casual      801170.0
# Flare         2540.0
# Novelty      11497.0
# OL             316.0
# Sexy        351186.0
# bohemian     46153.0
# cute        310001.0
# fashion        275.0
# party       108958.0
# sexy         77346.0
# vintage     144720.0
# work         64738.0
# dtype: float64

# %% [markdown]
# What is the percentage of “cute” and “Others” category in “Style” column in “Attribute DataSet” respectively?
# - 46%, 5%
# - 9%, 2.1%
# - 2.1%, 5%
# - 13.8%, 9%

# %%
# Calculate the percentage of each categories in the "Style" variable.
inp4.Style.value_counts(normalize = True)
# Out:
# Casual      0.457203
# Sexy        0.137787
# party       0.106472
# cute        0.091858
# vintage     0.052192
# bohemian    0.048017
# Brief       0.035491
# work        0.035491
# sexy        0.014614
# Novelty     0.012526
# Flare       0.004175
# OL          0.002088
# fashion     0.002088
# Name: Style, dtype: float64

# %% [markdown]
# Similarly Club Neckline, SLeeve length categories into "Others" which have less than 50000 sales across all the seasons.

# %%
# Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.
inp4
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 474   990559192    Brief  Average     4.7     M  winter     o-neck
# 475   713391965   Casual      Low     4.7     M  Spring     o-neck
# 476   532874347   Casual  Average     4.7     M  Summer     v-neck
# 477   655464934   Casual  Average     4.6     L  winter  boat-neck
# 478   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0      sleevless            NaN     chiffon     ruffles       animal
# ...

# %%
# Group "Sleeve length" categories into "Others" which have less than 50000 sales across all the seasons.
data.Season= data.Season.replace('Automn', "Autumn")

data.Season= data.Season.replace('spring', "Spring")

data.Season= data.Season.replace('winter', "Winter")



data.SleeveLength= data.SleeveLength.replace(['cap-sleeves', 'capsleeves'], "cap sleeves")

data.SleeveLength= data.SleeveLength.replace('full', "full sleeves")

data.SleeveLength= data.SleeveLength.replace(['half','halfsleeve'], "half sleeves")

data.SleeveLength= data.SleeveLength.replace(['sleevless', 'sleeevless', 'sleeveless', 'sleveless'], "sleeve less")

data.SleeveLength= data.SleeveLength.replace(['threequarter','threequater', 'thressqatar'], "three quater")

data.SleeveLength= data.SleeveLength.replace(['turndowncollor','urndowncollor'], "turn down collar")

# %% [markdown]
# Club material, fabrictype, patterntype and decoration categories into "Others" which have less than 25000 sales across all the seasons

# %%
# Group "material" categories into "Others" which have less than 25000 sales across all the seasons.
A = data[data.Season == 'Autumn']
A.drop(['Rating','Size','Season','NeckLine','SleeveLength','Material','FabricType','Decoration','Pattern Type','Recommendation','Style','Price','Dress_ID'], axis = 1, inplace = True)
# Out:
# C:\Users\GNYANESH\AppData\Local\Temp\ipykernel_24412\26347720.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A.drop(['Rating','Size','Season','NeckLine','SleeveLength','Material','FabricType','Decoration','Pattern Type','Recommendation','Style','Price','Dress_ID'], axis = 1, inplace = True)

# %%
# Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.
data.loc[data['09-12-2013']== 'Removed',"09-12-2013"] = np.NaN

data.loc[data['14-09-2013']== 'removed',"14-09-2013"] = np.NaN

data.loc[data['16-09-2013']== 'removed',"16-09-2013"] = np.NaN

data.loc[data['18-09-2013']== 'removed',"18-09-2013"] = np.NaN

data.loc[data['20-09-2013']== 'removed',"20-09-2013"] = np.NaN

data.loc[data['22-09-2013']== 'Orders',"22-09-2013"] = np.NaN

# %%
# Group "patern type" categories into "Others" which have less than 25000 sales across all the seasons.
A['09-12-2013'] = A['09-12-2013'].astype('int')
A['14-09-2013'] = A['14-09-2013'].astype('int')
A['16-09-2013'] = A['16-09-2013'].astype('int')
A['18-09-2013'] = A['18-09-2013'].astype('int')
A['20-09-2013'] = A['20-09-2013'].astype('int')
A['22-09-2013'] = A['22-09-2013'].astype('int')
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66 entries, 2 to 465
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   29-08-2013  66 non-null     int64
#  1   31-08-2013  66 non-null     int64
#  2   09-02-2013  66 non-null     int64
#  3   09-04-2013  66 non-null     int64
#  4   09-06-2013  66 non-null     int64
#  5   09-08-2013  66 non-null     int64
#  6   09-10-2013  66 non-null     int64
#  7   09-12-2013  66 non-null     int32
#  8   14-09-2013  66 non-null     int32
#  9   16-09-2013  66 non-null     int32
#  10  18-09-2013  66 non-null     int32
#  11  20-09-2013  66 non-null     int32
#  12  22-09-2013  66 non-null     int32
#  13  24-09-2013  66 non-null     int64
#  14  26-09-2013  30 non-null     float64
#  15  28-09-2013  66 non-null     int64
#  16  30-09-2013  25 non-null     float64
#  17  10-02-2013  25 non-null     float64
#  18  10-04-2013  25 non-null     float64
# ...

# %%
# Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.
A.sum().plot.box()
plt.show()

# %%
A.sum().describe()
# Out:
# count       23.000000
# mean     20271.565217
# std      10243.844120
# min       2868.000000
# 25%      13570.000000
# 50%      25355.000000
# 75%      27491.000000
# max      30997.000000
# dtype: float64

# %% [markdown]
# ### Caregorical Ordered Univariate Analysis

# %% [markdown]
# Which of the following is an unordered variable in “Attribute DataSet”.
# - Style
# - Price
# - Season
# - Size

# %% [markdown]
# ### Numerical variable Univariate analysis:

# %% [markdown]
# What is the approximate difference between the maximum value and 75th percentile in “Autumn” column.
# - Approx 54000
# - Approx 55000
# - Approx 52000
# - Approx 50000

# %%
# Describe the numerical variale: "Autumn".
W = data[data.Season == 'Winter']
W.drop(['Rating','Size','Season','NeckLine','SleeveLength','Material','FabricType','Decoration','Pattern Type','Recommendation','Style','Price','Dress_ID'], axis = 1, inplace = True)
W = W.dropna()
W['09-12-2013'] = W['09-12-2013'].astype('int')
W['14-09-2013'] = W['14-09-2013'].astype('int')
W['16-09-2013'] = W['16-09-2013'].astype('int')
W['18-09-2013'] = W['18-09-2013'].astype('int')
W['20-09-2013'] = W['20-09-2013'].astype('int')
W['22-09-2013'] = W['22-09-2013'].astype('int')
W.sum().describe()
# Out:
# C:\Users\GNYANESH\AppData\Local\Temp\ipykernel_24412\869157229.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   W.drop(['Rating','Size','Season','NeckLine','SleeveLength','Material','FabricType','Decoration','Pattern Type','Recommendation','Style','Price','Dress_ID'], axis = 1, inplace = True)
# C:\Users\GNYANESH\AppData\Local\Temp\ipykernel_24412\869157229.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   W['09-12-2013'] = W['09-12-2013'].astype('int')
# ...

# %%
# plot the boxplot of "Autumn" column.
S = data[data.Season == 'Summer']
S.drop(['Rating','Size','Season','NeckLine','SleeveLength','Material','FabricType','Decoration','Pattern Type','Recommendation','Style','Price','Dress_ID'], axis = 1, inplace = True)
S = S.dropna()
S['09-12-2013'] = S['09-12-2013'].astype('int')
S['14-09-2013'] = S['14-09-2013'].astype('int')
S['16-09-2013'] = S['16-09-2013'].astype('int')
S['18-09-2013'] = S['18-09-2013'].astype('int')
S['20-09-2013'] = S['20-09-2013'].astype('int')
S['22-09-2013'] = S['22-09-2013'].astype('int')
S.sum().describe()
# Out:
# C:\Users\GNYANESH\AppData\Local\Temp\ipykernel_24412\2217311897.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S.drop(['Rating','Size','Season','NeckLine','SleeveLength','Material','FabricType','Decoration','Pattern Type','Recommendation','Style','Price','Dress_ID'], axis = 1, inplace = True)
# C:\Users\GNYANESH\AppData\Local\Temp\ipykernel_24412\2217311897.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S['09-12-2013'] = S['09-12-2013'].astype('int')
# ...

# %% [markdown]
# Which of the following season has the highest difference between the maximum value and 99th quantile of sales?
# - Winter
# - Summer
# - Spring
# - Autumn

# %%
# Find the maximum and 99th percentile of Winter season.
SP = data[data.Season == 'Spring']
SP.drop(['Rating','Size','Season','NeckLine','SleeveLength','Material','FabricType','Decoration','Pattern Type','Recommendation','Style','Price','Dress_ID'], axis = 1, inplace = True)
SP= W.dropna()
SP['09-12-2013'] = SP['09-12-2013'].astype('int')
SP['14-09-2013'] = SP['14-09-2013'].astype('int')
SP['16-09-2013'] = SP['16-09-2013'].astype('int')
SP['18-09-2013'] = SP['18-09-2013'].astype('int')
SP['20-09-2013'] = SP['20-09-2013'].astype('int')
SP['22-09-2013'] = SP['22-09-2013'].astype('int')
SP.sum().describe()
# Out:
# C:\Users\GNYANESH\AppData\Local\Temp\ipykernel_24412\465897714.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SP.drop(['Rating','Size','Season','NeckLine','SleeveLength','Material','FabricType','Decoration','Pattern Type','Recommendation','Style','Price','Dress_ID'], axis = 1, inplace = True)
# count      23.000000
# mean     7628.000000
# std      1516.886764
# min      3893.000000
# 25%      7305.500000
# 50%      7956.000000
# 75%      8680.000000
# max      9435.000000
# dtype: float64

# %%
# Find the maximum and 99th percentile of Summer season.

# %%
# Find the maximum and 99th percentile of Spring season.

# %%
# Find the maximum and 99th percentile of Autumn season.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical- Categorical analysis

# %% [markdown]
# Which of the following “Price” category has the lowest average value of rating?
# - very-high
# - Medium
# - Low
# - High

# %%
# Find the Mean of Ratings for each Price category.
inp0.groupby('Price')['Rating'].mean()
# Out:
# Price
# Average      3.455042
# High         2.914286
# Low          3.731481
# Medium       3.156667
# very-high    3.123810
# Name: Rating, dtype: float64

# %% [markdown]
# What is the median of the rating of “vintage” category in Style column?
# - 4.6
# - 4.7
# - 4.55
# - 0.00

# %%
# Find the median of Ratings for each Style category.
inp0.groupby('Style')['Rating'].median()
# Out:
# Style
# Brief       4.6
# Casual      4.6
# Flare       0.0
# Novelty     2.1
# OL          0.0
# Sexy        4.6
# bohemian    4.6
# cute        4.6
# fashion     4.0
# party       4.7
# sexy        4.5
# vintage     4.6
# work        4.7
# Name: Rating, dtype: float64

# %% [markdown]
# Which of the following season has the highest average value of sale for “Recommendation” value equals to 1.
# - Summer
# - Spring
# - Autumn
# - Winter

# %%
# Summer sale vs Recommendation.
inp0.groupby('Season')['Recommendation'].sum()
# Out:
# Season
# Autumn    22
# Spring    71
# Summer    51
# Winter    56
# Name: Recommendation, dtype: int64

# %%
# Spring sale vs Recommendation.
inp0
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Autumn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 474   990559192    Brief  Average     4.7     M  Winter     o-neck
# 475   713391965   Casual      Low     4.7     M  Spring     o-neck
# 476   532874347   Casual  Average     4.7     M  Summer     v-neck
# 477   655464934   Casual  Average     4.6     L  Winter  boat-neck
# 478   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#      SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0     sleeve less        Missing     chiffon     ruffles       animal
# ...

# %%
# Autumn sale vs Recommendation.

# %%
# Winter sale vs Recommendation.

# %% [markdown]
# ### Categorical categorical bivariate analysis

# %% [markdown]
# Which of the following size categories has the highest positive recommendations?
# - Medium and extra large
# - Extra large and small
# - Free and small
# - Free and medium

# %%
# Size vs Recommendation.
inp0.groupby('Size')['Recommendation'].sum()
# Out:
# Size
# L        33
# M        76
# S        13
# XL        4
# free     74
# s         0
# small     0
# Name: Recommendation, dtype: int64

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# Which of the following pair of “Style” and “Price” category has the highest average of positive recommendations?
# - Price: medium and style: vintage
# - Price: medium and style: cute
# - Price: very high and style: party
# - Price: low and style: sexy

# %%
# plot the heat map of Style, price and Recommendation.
q = pd.pivot_table(data = inp0, values = 'Recommendation', index = 'Style', columns = 'Price', dropna = True)
sns.heatmap(q, annot = True, cmap = 'RdYlGn')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Style'>

# %% [markdown]
# Which of the following material type has no recommendation in summer and winter seasons?
# - Mix and Milksilk
# - Nylon and Rayon
# - Microfiber and Silk
# - Milksilk and Microfiber

# %%
# plot the heat map of Season, material and Recommendation.
fig = plt.figure(figsize = (10,10))
r = pd.pivot_table(data = inp0, values = 'Recommendation', index = 'Season', columns = 'Material', dropna = True)
sns.heatmap(r, annot = True, cmap = 'RdYlGn')
plt.show()
